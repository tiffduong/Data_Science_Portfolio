# %% [markdown]
# <a href="https://colab.research.google.com/github/tiffduong/Data_Science_Portfolio/blob/master/Assignment_3_Landmark_Detection_(Google_Vision_API).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3 - Landmark Detection using Google Vision API

# %% [markdown]
# ##Import Dependencies

# %%
import os
import glob

import matplotlib.pyplot as plt
# %matplotlib inline

from google.cloud import vision

# %% [markdown]
# ## Initialize Google Vision API

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/content/drive/My Drive/MSDS 462/Module3_API.json'

# %%
client = vision.ImageAnnotatorClient()

# %% [markdown]
# ## Google Vision API - Landmark Detection
# ###### Test Images extracted from Google Images

# %%
# display images in a directory, landmarks, and lat/long of landmarks

def LandmarkDetection():
  #iterate through a dir and open all files
  for file in glob.glob(directory+'/*'):
    f = open(file, 'rb')
    content = f.read()

    # plot image
    a = plt.imread(f)
    plt.imshow(a)
    plt.xticks([])
    plt.yticks([])
    plt.show()
    
    #request for Vision API
    image = vision.types.Image(content = content)
    response = client.landmark_detection(image = image)
    landmarks = response.landmark_annotations

    # print landmark and lat/long
    for landmark in landmarks:
      print('Landmark: {}'.format(landmark.description))
      print('Score: {} %'.format(round(landmark.score*100, 2)))
      for location in landmark.locations:
        print('Latitude: {}, Longitude: {}\n'.format(
            round(location.lat_lng.latitude, 5), round(location.lat_lng.longitude, 5)))

# %%
#define the directory:
directory = r'/content/drive/My Drive/MSDS 462/Landmark Images'

#intialize function
LandmarkDetection()
# Out:
# Landmark: Statue of Liberty
# Score: 86.18 %
# Latitude: 40.68926, Longitude: -74.04448
#
# Landmark: Statue of Liberty National Monument
# Score: 75.52 %
# Latitude: 40.68925, Longitude: -74.0445
# Landmark: Piazza dei Miracoli
# Score: 81.87 %
# Latitude: 43.72286, Longitude: 10.39581
# Landmark: Golden Gate National Recreation Area
# Score: 80.01 %
# Latitude: 37.84804, Longitude: -122.52953
#
# Landmark: Golden Gate Bridge
# Score: 50.52 %
# Latitude: 37.81101, Longitude: -122.4778
#
# Landmark: Battery Spencer
# Score: 40.66 %
# Latitude: 37.82771, Longitude: -122.48166
# Landmark: Taj Mahal
# Score: 90.49 %
# Latitude: 27.1747, Longitude: 78.04207
#
# Landmark: Taj Mahal Garden
# Score: 80.32 %
# Latitude: 27.17324, Longitude: 78.04214
#
# Landmark: Taj Mahal
# Score: 67.18 %
# Latitude: 27.1667, Longitude: 77.96096
#
# Landmark: Taj Mahal
# Score: 46.64 %
# Latitude: 27.18983, Longitude: 78.01735
# Landmark: Chichen Itza
# Score: 95.13 %
# ...
